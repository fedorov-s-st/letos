# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#описание-проекта" data-toc-modified-id="описание-проекта-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>описание проекта</a></span></li></ul></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#поиск-пропусков" data-toc-modified-id="поиск-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>поиск пропусков</a></span><ul class="toc-item"><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Исследование-категориальных-тренировачных-признаков" data-toc-modified-id="Исследование-категориальных-тренировачных-признаков-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Исследование категориальных тренировачных признаков</a></span></li><li><span><a href="#Исследование-количественных-тренировачных-признаков" data-toc-modified-id="Исследование-количественных-тренировачных-признаков-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Исследование количественных тренировачных признаков</a></span></li><li><span><a href="#Исследование-категориальных-тестовых-признаков" data-toc-modified-id="Исследование-категориальных-тестовых-признаков-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Исследование категориальных тестовых признаков</a></span></li><li><span><a href="#Исследование-количественных-тренировачных-признаков" data-toc-modified-id="Исследование-количественных-тренировачных-признаков-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Исследование количественных тренировачных признаков</a></span></li></ul></li><li><span><a href="#Корреляционный-анализ-тренировачного-датасета" data-toc-modified-id="Корреляционный-анализ-тренировачного-датасета-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Корреляционный анализ тренировачного датасета</a></span></li><li><span><a href="#Корреляционный-анализ-тестового-датасета" data-toc-modified-id="Корреляционный-анализ-тестового-датасета-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Корреляционный анализ тестового датасета</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Создание-метрики-SMAPE" data-toc-modified-id="Создание-метрики-SMAPE-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Создание метрики SMAPE</a></span></li><li><span><a href="#модель-линейной-регресии" data-toc-modified-id="модель-линейной-регресии-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>модель линейной регресии</a></span></li><li><span><a href="#модель-дерева-регресии" data-toc-modified-id="модель-дерева-регресии-5.0.3"><span class="toc-item-num">5.0.3&nbsp;&nbsp;</span>модель дерева регресии</a></span></li></ul></li></ul></li><li><span><a href="#Оформление-выводов" data-toc-modified-id="Оформление-выводов-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оформление выводов</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#поиск-пропусков" data-toc-modified-id="поиск-пропусков-8.0.1"><span class="toc-item-num">8.0.1&nbsp;&nbsp;</span>поиск пропусков</a></span></li><li><span><a href="#поиск-дубликатов" data-toc-modified-id="поиск-дубликатов-8.0.2"><span class="toc-item-num">8.0.2&nbsp;&nbsp;</span>поиск дубликатов</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Исследование-категориальных-тренировачных-признаков" data-toc-modified-id="Исследование-категориальных-тренировачных-признаков-9.0.1"><span class="toc-item-num">9.0.1&nbsp;&nbsp;</span>Исследование категориальных тренировачных признаков</a></span></li><li><span><a href="#Исследование-количественных-тренировачных-признаков" data-toc-modified-id="Исследование-количественных-тренировачных-признаков-9.0.2"><span class="toc-item-num">9.0.2&nbsp;&nbsp;</span>Исследование количественных тренировачных признаков</a></span></li><li><span><a href="#Исследование-целевого-признака-тестовых-данных" data-toc-modified-id="Исследование-целевого-признака-тестовых-данных-9.0.3"><span class="toc-item-num">9.0.3&nbsp;&nbsp;</span>Исследование целевого признака тестовых данных</a></span></li><li><span><a href="#Портрет-«уволившегося-сотрудника»" data-toc-modified-id="Портрет-«уволившегося-сотрудника»-9.0.4"><span class="toc-item-num">9.0.4&nbsp;&nbsp;</span>Портрет «уволившегося сотрудника»</a></span></li><li><span><a href="#визуализируйте-и-сравните-распределения-признака-job_satisfaction_rate" data-toc-modified-id="визуализируйте-и-сравните-распределения-признака-job_satisfaction_rate-9.0.5"><span class="toc-item-num">9.0.5&nbsp;&nbsp;</span>визуализируйте и сравните распределения признака job_satisfaction_rate</a></span></li></ul></li></ul></li><li><span><a href="#Добавление-нового-входного-признака" data-toc-modified-id="Добавление-нового-входного-признака-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Добавление нового входного признака</a></span><ul class="toc-item"><li><span><a href="#Корреляционный-анализ-тренировачного-датасета" data-toc-modified-id="Корреляционный-анализ-тренировачного-датасета-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Корреляционный анализ тренировачного датасета</a></span></li><li><span><a href="#Корреляционный-анализ-тестового-датасета" data-toc-modified-id="Корреляционный-анализ-тестового-датасета-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Корреляционный анализ тестового датасета</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Обучение моделей</a></span></li><li><span><a href="#вывод" data-toc-modified-id="вывод-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>вывод</a></span></li></ul></div>

# %% [markdown]
# ### описание проекта

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.

# %% [markdown]
# # Задача:  Предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ## Загрузка данных

# %%
pip install -U scikit-learn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install phik -q

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import (OneHotEncoder, 
                                     OrdinalEncoder, 
                                     StandardScaler, 
                                     MinMaxScaler, 
                                     RobustScaler,
                                     PolynomialFeatures)
from sklearn.linear_model import LinearRegression, Lasso, Ridge,LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC, SVR
from sklearn.metrics import roc_auc_score,r2_score,make_scorer
import  numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import phik
#import my_function as fc
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.feature_selection import SelectKBest,f_classif, mutual_info_classif  
from sklearn.preprocessing import LabelEncoder
import warnings
from sklearn.dummy import DummyRegressor, DummyClassifier


plt.rcParams["figure.figsize"] = (7,7)

warnings.filterwarnings('ignore')
RANDOM_STATE = 42

# %%
# поиск пропусков
def nan_search(datalist):
    for k, v in datalist.items():
        print(k,'\n')
        print(v.isna().sum())
        print('-'*50)

#поиск дубликатов
def dublic_search(datalist):
    for k, v in datalist.items():
        print(k,'\n')
        print(v.duplicated().sum())
        print('-'*50)
# функция кругового графика
def pie(df,title):
    colors = sns.color_palette("light:#5A9")
    df.plot(kind='pie',autopct='%1.1f%%',
                                      figsize=(6,6),colors=colors,shadow=True,
                                      title = title);
    plt.show()
# функция для построения графиков разбиных на категориальные step =1, и количественные step=2
def analysis(df, step:int):
    if step==1:
        for i in df.select_dtypes(include='object').columns:
            print('-----',i,'-----')
            print(df[i].value_counts())
            print()
            pie(df[i].value_counts(), i);
    if step==2:
        for i in df.select_dtypes(exclude='object').columns:
            print('------',i,'---------')
            print(df[i].describe())
            print()
            boxhist(data=df, x=i, title=i);

# ящик с усами
def boxplot(data, x, title):
    sns.boxplot(data=data, x=x,palette="crest");
    plt.title(title)
    plt.show()

# функция для построения ящика с усами и хистограмы для просмотра распределения
def boxhist(data, x, title):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    sns.boxplot(ax=axes[0],data=data, x=x,palette="crest");
    axes[0].set_xlabel(title)
    axes[0].set_title(title)


    sns.histplot(ax=axes[1],data=data, x=x, kde=True, palette="crest");
    axes[1].set_title(title);
    axes[1].set_xlabel(title)
    axes[1].axvline(data[x].mean(), c='k', ls='-', lw=2.5)
    axes[1].axvline(data[x].median(), c='orange', ls='--', lw=2.5)
    plt.xlabel(title);
    plt.show()

def emissions(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = 1.5 * (q3 -q1)
    df.loc[df[column]>q3+iqr, column]=q3+iqr
    df.loc[df[column]<q1-iqr, column]=q1-iqr
    return df

def scatter(data,x,y,hue, xlabel, ylabel, title):
    #plt.figure(figsize=(5,5))
    sns.scatterplot(data=data, x=x,y=y, hue=hue, palette="crest");
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

def barplot(data, x, y, xlabel, ylabel, rotation, title):
    #plt.figure(figsize=(15,3))
    sns.barplot(palette=sns.color_palette("crest"),data=data, x=x, y=y);
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation = rotation)
    plt.title(title)
    plt.show()
    
def count(data, xtitle, ytitle, title):
    sns.countplot(data,palette="crest");

    plt.xlabel(xtitle)
    plt.ylabel(ytitle)
    plt.title(title)
    plt.show()

# %%
try: 
    data_one_train = pd.read_csv('C:/Users/Serg/practicum/project_2/dataset/train_job_satisfaction_rate.csv')
    data_test = pd.read_csv('C:/Users/Serg/practicum/project_2/dataset/test_features.csv')
    data_one_test_true = pd.read_csv('C:/Users/Serg/practicum/project_2/dataset/test_target_job_satisfaction_rate.csv')
except:  
    data_one_train = pd.read_csv('/datasets/train_job_satisfaction_rate.csv')
    data_test = pd.read_csv('/datasets/test_features.csv')
    data_one_test_true = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv')

# %%
data_test = data_test.merge(data_one_test_true, on='id',how='left')

# %%
data_one_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %%
data_one_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB

# %%
data_test.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      5   28800                   0.79
# 1                   no                      4   30000                   0.72
# 2                   no                      4   19200                   0.64
# 3                   no                      4   19200                   0.60
# 4                   no                      5   40800                   0.75

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
#  9   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 171.9+ KB

# %%
data_one_test_true.head()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %%
data_one_test_true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# Данные загруженны и просмотренны. имена столбцов приведенны к стандарту.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### поиск пропусков

# %%
datalist = {'train':data_one_train,'test':data_test,'test_true':data_one_test_true}
nan_search(datalist)
# Out:
# train
#
# id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64
# --------------------------------------------------
# test
#
# id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64
# --------------------------------------------------
# test_true
#
# id                       0
# job_satisfaction_rate    0
# dtype: int64
# --------------------------------------------------

# %% [markdown]
# Пропуски присутствуют в тренировачных и тестовых данных. Заменим их в пайплане. Т.к. пропуски категориальные пременим стратегию заменяющий пропуски на самые популярные в столбце значения.

# %%
# пайплан обработки пропусков.
pip_nan = Pipeline(
     # Замена возможных пропусков на самое часто втречающиеся значение.
    [('simpleImputer', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))])

# %%
data_one_train=pip_nan.fit_transform(data_one_train)
columns=pip_nan.get_feature_names_out()
data_one_train=pd.DataFrame(data=data_one_train, columns=columns)

# %%
v=pip_nan.transform(data_test)
columns=pip_nan.get_feature_names_out()
data_test=pd.DataFrame(data=v, columns=columns)

# %%
data_test.isna().sum()
# Out:
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64

# %%
datalist ={'train':data_one_train,'test':data_test,'test_true':data_one_test_true}
nan_search(datalist)
# Out:
# train
#
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64
# --------------------------------------------------
# test
#
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64
# --------------------------------------------------
# test_true
#
# id                       0
# job_satisfaction_rate    0
# dtype: int64
# --------------------------------------------------

# %% [markdown]
# Все пропуски заменили.

# %% [markdown]
# Вернем количественным данным- числовой тип данных

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   object
#  1   dept                   2000 non-null   object
#  2   level                  2000 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   object
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   object
#  8   salary                 2000 non-null   object
#  9   job_satisfaction_rate  2000 non-null   object
# dtypes: object(10)
# memory usage: 156.4+ KB

# %%
int_num = ['employment_years','supervisor_evaluation','salary']
data_one_train[int_num ]=data_one_train[int_num ].astype('int64')
data_test[int_num ]= data_test[int_num ].astype('int64')
data_one_train['job_satisfaction_rate']= data_one_train['job_satisfaction_rate'].astype('float64')

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   object
#  1   dept                   2000 non-null   object
#  2   level                  2000 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
#  9   job_satisfaction_rate  2000 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 156.4+ KB

# %%
data_test[int_num ]= data_test[int_num ].astype('int64')
data_test['job_satisfaction_rate']= data_test['job_satisfaction_rate'].astype('float64')

# %% [markdown]
# #### Поиск дубликатов

# %%
data_one_train=data_one_train.drop(['id'], axis=1)
data_test=data_test.drop(['id'], axis=1)

# %%
# поиск дубликатов
print('Дубликатов до удаления:',data_one_train.duplicated().sum())
# удаление дубликатов
data_one_train = data_one_train.drop_duplicates()
print('После удаления:',data_one_train.duplicated().sum())
# Out:
# Дубликатов до удаления: 248
# После удаления: 0

# %% [markdown]
# Явных дубликатов не найдно.

# %%
for  k ,v in datalist.items():
    try:
        print(k)
        v=v.select_dtypes(include='object')
        for i in range(0,len(v)):
            print(v.iloc[:,i].unique())
        print('__'*50) 
    except:
        continue
# Out:
# train
# [155278 653870 184592 ... 533318 706868 338347]
# ['sales' 'hr' 'technology' 'purchasing' 'marketing']
# ['junior' 'middle' 'sinior']
# ['medium' 'high' 'low']
# ['no' 'yes']
# ['no' 'yes']
# test
# [485046 686555 467458 ... 305653 160233 771859]
# ['marketing' 'hr' 'sales' 'purchasing' 'technology' ' ']
# ['junior' 'middle' 'sinior']
# ['medium' 'low' 'high' ' ']
# ['no' 'yes']
# ['no' 'yes']
# test_true

# %% [markdown]
# Неявных дубликатов не обнаруженно.
# Но в тестовых данных присутствует пропуск.

# %%
row_i = data_test.loc[data_test['workload']==' '].index[0]
col_i =data_test.columns.get_loc('workload')
data_test.loc[data_test['workload']==' ']
# Out:
#          dept   level workload  employment_years last_year_promo  \
# 15  marketing  junior                          4              no
#
#    last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 15                   no                      4   28800                   0.79

# %%
data_test.iloc[row_i,col_i]= data_test.loc[data_test['level']=='junior', 'workload'].mode()[0]

# %%
row_i = data_test.loc[data_test['dept']==' '].index[0]
col_i = data_test.columns.get_loc('dept')
data_test.loc[data_test['dept']==' ']
# Out:
#      dept   level workload  employment_years last_year_promo  \
# 1699       middle   medium                 3              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1699                   no                      4   38400
#
#       job_satisfaction_rate
# 1699                   0.64

# %% [markdown]
# Заполним пропуск самым частым значчением в столбце, отсортированным по столбцу `level`

# %%
data_test.iloc[row_i,col_i]= data_test.loc[data_test['workload']=='medium', 'dept'].mode()[0]

# %% [markdown]
# **Вывод**
#
# Провели предобработку данных. Заменили пропуски категориальных признаков самыми частыми значениями.
# Нашли пропуск в виде пустого значения и так же заменили его.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# #### Исследование категориальных тренировачных признаков

# %%
analysis(data_one_train, step=1)
# Out:
# ----- dept -----
# sales         1377
# technology     818
# purchasing     586
# marketing      531
# hr             440
# Name: dept, dtype: int64
# ----- level -----
# junior    1700
# middle    1695
# sinior     357
# Name: level, dtype: int64
# ----- workload -----
# medium    1905
# low       1125
# high       722
# Name: workload, dtype: int64
# ----- last_year_promo -----
# no     3632
# yes     120
# Name: last_year_promo, dtype: int64
# ----- last_year_violations -----
# no     3199
# yes     553
# Name: last_year_violations, dtype: int64

# %% [markdown]
# Больше всего сотрудников:
# -  работает в `sales` 38%
# -  имеют уровень `junior` 47.5%
# - имеют рабочую нагрузку `medium` 51.6%
# - 97% сотрудников не получали повышение в этом году
# - 14% - нарушали трудовой договор в этом году

# %% [markdown]
# #### Исследование количественных тренировачных признаков

# %%
analysis(data_one_train.drop(['supervisor_evaluation','employment_years'],axis=1), step=2)
# Out:
# ------ salary ---------
# count     3752.000000
# mean     34463.219616
# std      15055.252759
# min      12000.000000
# 25%      22800.000000
# 50%      31200.000000
# 75%      44400.000000
# max      98400.000000
# Name: salary, dtype: float64
# ------ job_satisfaction_rate ---------
# count    3752.000000
# mean        0.532535
# std         0.226424
# min         0.030000
# 25%         0.350000
# 50%         0.550000
# 75%         0.710000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %%
count(data_one_train['supervisor_evaluation'],'оценка качества работы сотрудника','кол-во','оценки качества работы сотрудников');

# %% [markdown]
# Чаще сотрудникам ставят оценку 4. Оклоло 200 человек имеют оценку 1.

# %%
count(data_one_train['employment_years'],
      'Длительность работы сотрудников','кол-во сотрудников','Длительность работы сотрудников, в годах');

# %% [markdown]
# Как видим основная часть сотрудников проработала в компании год или меньше. Сотрудников проработавших 10 лет всего около 100.

# %% [markdown]
# Можно сделать вывод, что `employment_years` и `supervisor_evaluation` можно сделать категориальными
# у `salary` есть выбросы. Имеет скошенное распределение.
# `job_satisfaction_rate` выбросов нет, имеет биноминальное распределение

# %% [markdown]
# #### Исследование категориальных тестовых признаков

# %%
analysis(data_test, step=1)
# Out:
# ----- dept -----
# sales         766
# technology    455
# marketing     279
# purchasing    273
# hr            227
# Name: dept, dtype: int64
# ----- level -----
# junior    975
# middle    854
# sinior    171
# Name: level, dtype: int64
# ----- workload -----
# medium    1044
# low        593
# high       363
# Name: workload, dtype: int64
# ----- last_year_promo -----
# no     1937
# yes      63
# Name: last_year_promo, dtype: int64
# ----- last_year_violations -----
# no     1738
# yes     262
# Name: last_year_violations, dtype: int64

# %% [markdown]
# В тестовых данных так же большинство:
# -  работает в `sales` 38.3%
# -  имеют уровень `junior` 48.8%
# - имеют рабочую нагрузку `medium` 52.2%
# - 97% сотрудников не получали повышение в этом году
# - 13% - нарушали трудовой договор в этом году

# %% [markdown]
# #### Исследование количественных тренировачных признаков

# %%
analysis(data_test.drop(['supervisor_evaluation','employment_years'],axis=1), step=2)
# Out:
# ------ salary ---------
# count     2000.000000
# mean     34066.800000
# std      15398.436729
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64
# ------ job_satisfaction_rate ---------
# count    2000.00000
# mean        0.54878
# std         0.22011
# min         0.03000
# 25%         0.38000
# 50%         0.58000
# 75%         0.72000
# max         1.00000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# `salary` присутствуют выбросы

# %%
count(data_test['supervisor_evaluation'],'оценка качества работы сотрудника','кол-во','оценки качества работы сотрудников');

# %% [markdown]
# Менее 100 человек имеют оценку 1.

# %%
count(data_test['employment_years'],
      'Длительность работы сотрудников','кол-во сотрудников','Длительность работы сотрудников, в годах');

# %% [markdown]
# Как видим основная часть сотрудников проработала в компании год или меньше. Сотрудников проработавших 10 лет всего меньше 100.

# %% [markdown]
# Разберемся с выбросами в ` salary`.  Замени значения выбросов на значение ближайшего "уса".

# %%
emissions(data_one_train, 'salary')
emissions(data_test,'salary')
# Out:
#             dept   level workload  employment_years last_year_promo  \
# 0      marketing  junior   medium                 2              no
# 1             hr  junior   medium                 1              no
# 2          sales  middle      low                 5              no
# 3          sales  middle      low                 6              no
# 4             hr  middle   medium                 5              no
# ...          ...     ...      ...               ...             ...
# 1995   marketing  junior      low                 3              no
# 1996  technology  middle      low                 3              no
# 1997  technology  junior      low                 1              no
# 1998  technology  middle      low                 8              no
# 1999  purchasing  middle   medium                 1              no
#
#      last_year_violations  supervisor_evaluation   salary  \
# 0                      no                      5  28800.0
# ...

# %% [markdown]
# Для моделирования стобцы `employment_years` и `supervisor_evaluation` превратим в категориальные признаки.

# %% [markdown]
# ### Корреляционный анализ тренировачного датасета

# %%
numlist=['salary', 'job_satisfaction_rate']
cf = data_one_train.phik_matrix(interval_cols=numlist) 
cf.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_17a9d_row0_col0,#T_17a9d_row1_col1,#T_17a9d_row2_col2,#T_17a9d_row3_col3,#T_17a9d_row4_col4,#T_17a9d_row5_col5,#T_17a9d_row6_col6,#T_17a9d_row7_col7,#T_17a9d_row8_col8{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_17a9d_row0_col1,#T_17a9d_row0_col4,#T_17a9d_row0_col5,#T_17a9d_row1_col0,#T_17a9d_row1_col5,#T_17a9d_row1_col6,#T_17a9d_row2_col5,#T_17a9d_row2_col8,#T_17a9d_row3_col6,#T_17a9d_row4_col0,#T_17a9d_row5_col0,#T_17a9d_row5_col1,#T_17a9d_row5_col2,#T_17a9d_row5_col7,#T_17a9d_row6_col1,#T_17a9d_row6_col3{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_17a9d_row0_col2,#T_17a9d_row2_col0,#T_17a9d_row4_col6,#T_17a9d_row6_col4{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_17a9d_row0_col3,#T_17a9d_row3_col0{
#             background-color:  #f2f8fd;
#             color:  #000000;
# ...

# %% [markdown]
# ### Корреляционный анализ тестового датасета

# %%
cf = data_test.phik_matrix(interval_cols=numlist) 
cf.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_a1d27_row0_col0,#T_a1d27_row1_col1,#T_a1d27_row2_col2,#T_a1d27_row3_col3,#T_a1d27_row4_col4,#T_a1d27_row5_col5,#T_a1d27_row6_col6,#T_a1d27_row7_col7,#T_a1d27_row8_col8{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_a1d27_row0_col1,#T_a1d27_row0_col3,#T_a1d27_row0_col4,#T_a1d27_row0_col5,#T_a1d27_row1_col0,#T_a1d27_row1_col6,#T_a1d27_row2_col5,#T_a1d27_row2_col8,#T_a1d27_row3_col0,#T_a1d27_row3_col6,#T_a1d27_row4_col0,#T_a1d27_row4_col5,#T_a1d27_row5_col0,#T_a1d27_row5_col2,#T_a1d27_row5_col4,#T_a1d27_row5_col7,#T_a1d27_row6_col1,#T_a1d27_row6_col3,#T_a1d27_row7_col5{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_a1d27_row0_col2,#T_a1d27_row2_col0{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_a1d27_row0_col6,#T_a1d27_row6_col0{
#             background-color:  #ebf3fb;
#             color:  #000000;
# ...

# %% [markdown]
# Линейной зависимости между целевым признаком и зарплатой нет.

# %% [markdown]
# Мультиколлинеарность не наблюдается

# %% [markdown]
# ## Подготовка данных

# %%
X_train = data_one_train.drop(['job_satisfaction_rate'],axis=1)
y_train = data_one_train['job_satisfaction_rate']
X_test = data_test.drop(['job_satisfaction_rate'],axis=1)
y_test = data_test['job_satisfaction_rate']

# %%
# объявляем селектор и рапределяем столбцы.
selector = SelectKBest(f_classif, k=14)
selector_tree = SelectKBest(f_classif,k=8)
col_ohe_lr = list(X_train.select_dtypes(include='object').columns)
col_ohe_tree = list(X_train.select_dtypes(include='object').columns)
col_ord = ['level','workload']
col_num = list(X_train.select_dtypes(exclude='object').columns)

# %% [markdown]
# Создадим пайплан для кодирования признаков

# %%
# пайплан для кодирования методом OneHotEncoder
pipe_ohe = Pipeline([('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False))])

# %%
# пайплан для кодирования методом OrdinalEncoder
pipe_ord = ord_pipe = Pipeline([
    
    ('ord',  OrdinalEncoder(categories=[ ['junior','middle','sinior'],['low','medium','high']],
                            handle_unknown='use_encoded_value',unknown_value=-1))])

# %%
# пайплан для линейных моделей
preprocessor_lr = ColumnTransformer(
    [
    ('ohe', pipe_ohe, col_ohe_lr),
    ('num', MinMaxScaler(), col_num)
    ], 
    remainder='passthrough')

# %%
# объединяем пайпланы для модели дерева
preprocessor_tree = ColumnTransformer(
    [
    ('ohe', pipe_ohe, col_ohe_tree),
    ('ord', pipe_ord, col_ord),
    ('num', StandardScaler(), col_num)
    ], 
    remainder='passthrough')

# %%
# гиперпараметры дерева
param_grid_dtc =[{
        'models__max_depth': range(16,18),
        'models__min_samples_leaf': range(1,4),
        'models__max_features': range(11,14),
        'models__min_samples_split': range(7,10),
        'selector__k': range(1,16),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']
}]

# %%
# гиперпараметры линейных моделей
param_grid_lr = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [LinearRegression()],
        'selector__k': range(7,12),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [Ridge(random_state=RANDOM_STATE)],
        'models__alpha':[10,500,754,1000],
        'selector__k': range(7,12),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']   
    },
     {
        'models': [Lasso(random_state=RANDOM_STATE)],
        'models__alpha':[10,500,754,1000],
        'selector__k': range(7,12),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']   
    },
    ]

# %%
# создаем пайплан для  модели дерево решений
pipe_dtc = Pipeline(
    [('preprocessor', preprocessor_tree),
     ('selector', selector_tree),
    ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))]) 
# создаем пайплан для линейной  модели 
pipe_lr = Pipeline(
    [('preprocessor', preprocessor_lr),
    ('selector', selector),
    ('models', LinearRegression())])

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# #### Создание метрики SMAPE

# %%
# метрика SMAPE
def smape(A, F):
    return 100/len(A) * np.sum(np.abs(F - A) / ((np.abs(A) + np.abs(F))/2))

# %%
smape_score = make_scorer(smape,greater_is_better=False)

# %% [markdown]
# #### модель линейной регресии

# %%
# Найдем лучшую модель из линейных и регулиризаций
randomized_search_lr = RandomizedSearchCV(
    pipe_lr, 
    param_grid_lr, 
    cv=5,
    scoring=smape_score,
    n_jobs=-1
)

randomized_search_lr.fit(X_train, y_train)



print('Лучшая модель и её параметры:\n\n', randomized_search_lr.best_estimator_)
print ('Метрика кросс-валидации лучшей модели на тренировочной выборке:', randomized_search_lr.best_score_*-1)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'level', 'workload',
#                                                    'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('num', MinMaxScaler(),
#                                                   ['employment_years',
# ...

# %%
# Метрика на обучающих данных
smape(y_train, randomized_search_lr.predict(X_train))
# Out:
# 26.57335850605136

# %% [markdown]
# #### модель дерева регресии

# %%
#лучшая праметры дерева регресии
grid_search_tree = RandomizedSearchCV(
    pipe_dtc, 
    param_grid_dtc, 
    cv=5,
    scoring=smape_score,
    error_score='raise',
    n_jobs=-1
)

grid_search_tree.fit(X_train, y_train)



print('Лучшая модель и её параметры:\n\n', grid_search_tree.best_estimator_)
print ('Метрика кросс-валидации лучшей модели на тренировочной выборке:', grid_search_tree.best_score_ *-1)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'level', 'workload',
#                                                    'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('ord',
# ...

# %%
result_tree = pd.DataFrame(grid_search_tree.cv_results_)
ind=result_tree.index[result_tree['rank_test_score']==1]
result_tree.loc[ind[0],'params']
# Out:
# {'selector__k': 15,
#  'preprocessor__num': MinMaxScaler(),
#  'models__min_samples_split': 9,
#  'models__min_samples_leaf': 3,
#  'models__max_features': 12,
#  'models__max_depth': 17}

# %%
X_train_dtr_final =pd.DataFrame(
    preprocessor_tree.fit_transform(X_train),
    columns=preprocessor_tree.get_feature_names_out() )   

X_test_dtr_final =pd.DataFrame(
    preprocessor_tree.fit_transform(X_test),
    columns=preprocessor_tree.get_feature_names_out())
    
selector.fit(X_train_dtr_final, y_train)
features_names = selector.get_feature_names_out()
X_train_dtr_final = X_train_dtr_final[list(features_names)]
X_test_dtr_final = X_test_dtr_final[list(features_names)]

# %% [markdown]
# Оценка лучшей модели на тестовой выборке

# %%
model_one = DecisionTreeRegressor(max_depth=17, max_features=11,min_samples_leaf=3,
                                       min_samples_split=9,random_state=RANDOM_STATE)
model_one.fit(X_train_dtr_final, y_train)

# Оценка лучшей модели на тестовой выборке
pred_one = model_one.predict(X_test_dtr_final)
smape(y_test, pred_one)
# Out:
# 13.478613840664705

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(X_train_dtr_final, y_train)
# Out:
# DummyRegressor()

# %%
dummy_regr.predict(X_test_dtr_final)
smape(y_test, dummy_regr.predict(X_test_dtr_final))
# Out:
# 38.262831018170885

# %% [markdown]
# Значение DummyRegressor -38%. оценка модели -13,4%

# %% [markdown]
# 22% значения SMAPE  модели логической регрессии на тестовой выборке.
# Лучшей оказалась дерево регрессии с 13.47% на тестовой выборке

# %% [markdown]
# ## Оформление выводов

# %% [markdown]
# Провели исследования и моделирование.
# - Были убраны пропуски и пустые значения у  нескольких столбцов были изменены тип данных.
# - Исправлены выбросы .
# - В качестве моделей были обучены линейная регрессия с 2 регулиризациями и дерево регрессии.Была найдена лучшая модель.
#
# Параметры лучшей модели: DecisionTreeRegressor() при 14 признаках
# - max_depth': 17,
# - max_features': 11,
# - min_samples_leaf': 3,
# - min_samples_split': 9,
# - 'метод масштабирования: StandardScaler(),

# %% [markdown]
# # Задача 2: предсказание увольнения сотрудника из компании

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В этой задаче по аналогичным активностям аналогичные замечания.

# %% [markdown]
# ## Загрузка данных

# %%
try:
    data_two_train = pd.read_csv('C:/Users/Serg/practicum/project_2/dataset/train_quit.csv')
    data_test = pd.read_csv('C:/Users/Serg/practicum/project_2/dataset/test_features.csv')
    data_two_test_true = pd.read_csv('C:/Users/Serg/practicum/project_2/dataset/test_target_quit.csv')
except:
    data_two_train = pd.read_csv('/datasets/train_quit.csv')
    data_test = pd.read_csv('/datasets/test_features.csv')
    data_two_test_true = pd.read_csv('/datasets/test_target_quit.csv')

# %%
data_two_train
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 0     723290       sales  middle     high                 2              no
# 1     814010       sales  junior   medium                 2              no
# 2     155091  purchasing  middle   medium                 5              no
# 3     257132       sales  junior   medium                 2              no
# 4     910140   marketing  junior   medium                 2              no
# ...      ...         ...     ...      ...               ...             ...
# 3995  588809       sales  junior   medium                 4              no
# 3996  672059       sales  middle     high                 9              no
# 3997  536432  purchasing  junior      low                 2              no
# 3998  692133  purchasing  middle   medium                 2              no
# 3999  853842       sales  junior   medium                 2              no
#
# ...

# %%
data_test = data_test.merge(data_two_test_true,on='id',how='left')

# %%
datalist = {'train':data_two_train,'test':data_test}

# %%
data_two_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
data_test.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      5   28800   no
# 1                   no                      4   30000   no
# 2                   no                      4   19200   no
# 3                   no                      4   19200   no
# 4                   no                      5   40800   no

# %%
for k,v in datalist.items():
    print(k,'\n')
    print(v.info())
    print('-'*50)
# Out:
# train
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
# None
# --------------------------------------------------
# test
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
# ...

# %% [markdown]
# Загрузили данныедля второй задачи.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# #### поиск пропусков

# %%
nan_search(datalist)
# Out:
# train
#
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# quit                     0
# dtype: int64
# --------------------------------------------------
# test
#
# id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# quit                     0
# dtype: int64
# --------------------------------------------------

# %% [markdown]
# Снова удалим пропуски в тестовых данных

# %%
data_two_train=pip_nan.fit_transform(data_two_train)
columns=pip_nan.get_feature_names_out()
data_two_train=pd.DataFrame(data=data_two_train, columns=columns)

# %%
v=pip_nan.transform(data_test)
columns=pip_nan.get_feature_names_out()
data_test=pd.DataFrame(data=v, columns=columns)

# %%
data_test.isna().sum()
# Out:
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# quit                     0
# dtype: int64

# %% [markdown]
# #### поиск дубликатов

# %%
data_two_train=data_two_train.drop(['id'], axis=1)
data_test=data_test.drop(['id'], axis=1)

# %%
datalist = {'train':data_two_train}
dublic_search(datalist)
# Out:
# train
#
# 1413
# --------------------------------------------------

# %% [markdown]
# Явных дубликатов 1413 дубликатов в тренировачных данных. Удалим их.

# %%
data_two_train = data_two_train.drop_duplicates()

# %%
for  k ,v in datalist.items():
    try:
        print(k)
        v=v.select_dtypes(include='object')
        for i in range(0,len(v)):
            print(v.iloc[:,i].unique())
        print('__'*50) 
    except:
        continue
# Out:
# train
# ['sales' 'purchasing' 'marketing' 'technology' 'hr']
# ['middle' 'junior' 'sinior']
# ['high' 'medium' 'low']
# [2 5 1 8 4 7 3 9 6 10]
# ['no' 'yes']
# ['no' 'yes']
# [4 1 3 5 2]
# [54000 27600 37200 24000 25200 18000 44400 19200 45600 57600 33600 16800
#  22800 26400 82800 32400 39600 30000 46800 12000 15600 58800 60000 66000
#  21600 38400 62400 40800 56400 34800 28800 52800 20400 36000 61200 48000
#  43200 73200 31200 78000 64800 72000 94800 96000 63600 79200 55200 42000
#  49200 50400 14400 13200 51600 67200 88800 68400 69600 70800 84000 81600
#  87600 75600 91200 76800 74400 80400 85200 86400 92400]
# ['no' 'yes']

# %%
row_i = data_test.loc[data_test['workload']==' '].index[0]
col_i =data_test.columns.get_loc('workload')
data_test.loc[data_test['workload']==' ']
data_test.iloc[row_i,col_i]= data_test.loc[data_test['level']=='junior', 'workload'].mode()[0]

# %%
row_i = data_test.loc[data_test['dept']==' '].index[0]
col_i = data_test.columns.get_loc('dept')
data_test.loc[data_test['dept']==' ']
data_test.iloc[row_i,col_i]= data_test.loc[data_test['workload']=='medium', 'dept'].mode()[0]

# %% [markdown]
# Неявных дубликатов не найдено. Удалили пустые значения.

# %%
int_num = ['employment_years','supervisor_evaluation','salary']
data_two_train[int_num ]=data_two_train[int_num ].astype('int64')

data_test[int_num ]= data_test[int_num ].astype('int64')

# %% [markdown]
# **Вывод**  Предобработали данные. Пропусков,дубликатов не найденно.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# #### Исследование категориальных тренировачных признаков

# %%
analysis(data_two_train, step=1)
# Out:
# ----- dept -----
# sales         805
# technology    581
# purchasing    430
# marketing     423
# hr            348
# Name: dept, dtype: int64
# ----- level -----
# middle    1282
# junior     958
# sinior     347
# Name: level, dtype: int64
# ----- workload -----
# medium    1244
# low        746
# high       597
# Name: workload, dtype: int64
# ----- last_year_promo -----
# no     2476
# yes     111
# Name: last_year_promo, dtype: int64
# ----- last_year_violations -----
# no     2111
# yes     476
# Name: last_year_violations, dtype: int64
# ----- quit -----
# no     1932
# yes     655
# Name: quit, dtype: int64

# %% [markdown]
# #### Исследование количественных тренировачных признаков

# %%
analysis(data_two_train.drop(['supervisor_evaluation','employment_years'],axis=1), step=2)
# Out:
# ------ salary ---------
# count     2587.000000
# mean     37107.692308
# std      16267.354906
# min      12000.000000
# 25%      24000.000000
# 50%      33600.000000
# 75%      46800.000000
# max      96000.000000
# Name: salary, dtype: float64

# %%
count(data_two_train['supervisor_evaluation'],'оценка качества работы сотрудника','кол-во','оценки качества работы сотрудников');

# %%
count(data_two_train['employment_years'],
      'Длительность работы сотрудников','кол-во сотрудников','Длительность работы сотрудников, в годах');

# %% [markdown]
# #### Исследование целевого признака тестовых данных

# %%
analysis(data_two_test_true, step=1)
# Out:
# ----- quit -----
# no     1436
# yes     564
# Name: quit, dtype: int64

# %% [markdown]
# Разберемся с выбросами в ` salary`.

# %%
emissions(data_two_train, 'salary')
emissions(data_test, 'salary')
# Out:
#             dept   level workload  employment_years last_year_promo  \
# 0      marketing  junior   medium                 2              no
# 1             hr  junior   medium                 1              no
# 2          sales  middle      low                 5              no
# 3          sales  middle      low                 6              no
# 4             hr  middle   medium                 5              no
# ...          ...     ...      ...               ...             ...
# 1995   marketing  junior      low                 3              no
# 1996  technology  middle      low                 3              no
# 1997  technology  junior      low                 1              no
# 1998  technology  middle      low                 8              no
# 1999  purchasing  middle   medium                 1              no
#
#      last_year_violations  supervisor_evaluation   salary quit
# 0                      no                      5  28800.0   no
# ...

# %% [markdown]
# #### Портрет «уволившегося сотрудника»

# %%
quit_df = data_two_train.loc[data_two_train['quit']=='yes']

# %%
quit_df[['supervisor_evaluation', 'employment_years']] = quit_df[['supervisor_evaluation', 'employment_years']].astype('object')

# %%
data_two_train.groupby('quit')['salary'].count()
# Out:
# quit
# no     1932
# yes     655
# Name: salary, dtype: int64

# %%
analysis(quit_df, step=1)
# Out:
# ----- dept -----
# sales         191
# technology    150
# purchasing    120
# marketing     112
# hr             82
# Name: dept, dtype: int64
# ----- level -----
# junior    537
# middle    101
# sinior     17
# Name: level, dtype: int64
# ----- workload -----
# low       291
# medium    255
# high      109
# Name: workload, dtype: int64
# ----- employment_years -----
# 1     276
# 2     178
# 3     128
# 4      25
# 5      22
# 6      10
# 7       7
# 8       3
# 9       3
# 10      3
# Name: employment_years, dtype: int64
# ----- last_year_promo -----
# no     654
# yes      1
# Name: last_year_promo, dtype: int64
# ----- last_year_violations -----
# no     475
# yes    180
# Name: last_year_violations, dtype: int64
# ----- supervisor_evaluation -----
# 3    272
# 4    148
# 2    123
# 1     69
# 5     43
# Name: supervisor_evaluation, dtype: int64
# ----- quit -----
# yes    655
# Name: quit, dtype: int64

# %%
k=data_two_train.groupby('quit')['salary'].mean()
print(k)
sns.barplot(k, k.index,palette=sns.color_palette("crest"));
plt.xlabel('Средняя зарплата')
plt.ylabel('Уволен ли сотрудник')
plt.title('График средней зарплаты у уволенных и работющих сотрудников')
plt.show()
# Out:
# quit
# no     40871.118012
# yes    25767.938931
# Name: salary, dtype: float64

# %%
k1=data_two_train.groupby('quit')['employment_years'].mean()
print(k1)
sns.barplot(k1, k1.index,palette=sns.color_palette("crest"));
plt.xlabel('Средняя продолжительность работы в компании,в годах')
plt.ylabel('Уволен ли сотрудник')
plt.title('График средней продолжительности работы в компании у уволенных и работющих сотрудников')
plt.show()
# Out:
# quit
# no     4.908903
# yes    2.161832
# Name: employment_years, dtype: float64

# %% [markdown]
# Основная часть уволившихся рабтников  проработала в компании в среднем чуть больше 2 лет.

# %%
k2=data_two_train.groupby('quit')['supervisor_evaluation'].mean()
print(k2)
sns.barplot(k2, k2.index,palette=sns.color_palette("crest"));
plt.xlabel('Средняя оценка работы сот-ка')
plt.ylabel('Уволен ли сотрудник')
plt.title('График средней оценки работы у уволенных и работющих сотрудников')
plt.show()
# Out:
# quit
# no     3.506729
# yes    2.958779
# Name: supervisor_evaluation, dtype: float64

# %% [markdown]
# Основная часть уволенных рабников имело среднию оценку работы менее 3.

# %% [markdown]
# По портрету «уволившегося сотрудника» можно сказать:
# -  скорее всего он работает в отделе `sales`.
# -  имеет уровень `junior`.
# -  имеет низкую рабочую нагрузку.
# - за последний год не было повышения
# - у 20 % уволившиеся были нарушения трудового договора за последний год.
# - Средняя оценка уволенных рабоников менее 3.
# - Средняя продолжительность работы в компании около 2 лет.
# - у уволившихся сотрудников в среднем зарплата меньше на 15 тысяч рублей.

# %% [markdown]
# #### визуализируйте и сравните распределения признака job_satisfaction_rate

# %%
yes = data_two_test_true.loc[data_two_test_true['quit']=='yes','id']
no = data_two_test_true.loc[data_two_test_true['quit']=='no','id']

# %%
quit_yes =data_one_test_true.copy()
quit_no = data_one_test_true.copy()

# %%
for i in yes.unique():
    quit_yes = quit_yes.loc[quit_yes['id']!=i].copy()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Тут лучше сделать фильтрцию вида `df[~df['id'.isin(yes.unique())]`. За счёт `~` мы получаем обратный результат от условиям фильтрации, то есть строки, где `id` нет в `yes.unique()`.

# %%
analysis(quit_yes.drop(['id'],axis=1),step=2)
# Out:
# ------ job_satisfaction_rate ---------
# count    1436.000000
# mean        0.612040
# std         0.199367
# min         0.030000
# 25%         0.500000
# 50%         0.660000
# 75%         0.760000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %%
for i in no.unique():
    quit_no = quit_no.loc[quit_no['id']!=i].copy()
analysis(quit_no.drop(['id'],axis=1),step=2)
# Out:
# ------ job_satisfaction_rate ---------
# count    564.000000
# mean       0.387713
# std        0.185784
# min        0.040000
# 25%        0.240000
# 50%        0.370000
# 75%        0.492500
# max        0.970000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# Для обоих категорий сотрудников разпределения признака разные.

# %%
data_one_test_true = data_one_test_true.merge(data_two_test_true, on='id',how='left')

# %%
data_one_test_true
# Out:
#           id  job_satisfaction_rate quit
# 0     130604                   0.74   no
# 1     825977                   0.75   no
# 2     418490                   0.60  yes
# 3     555320                   0.72   no
# 4     826430                   0.08  yes
# ...      ...                    ...  ...
# 1995  405257                   0.28   no
# 1996  370925                   0.21  yes
# 1997  857722                   0.39   no
# 1998  303402                   0.26  yes
# 1999  648995                   0.62   no
#
# [2000 rows x 3 columns]

# %%
scatter(data_one_test_true,x="job_satisfaction_rate",y='id',hue='quit', xlabel='уровень удовлетворённости сотрудника работой',
        ylabel='', title='увольнения и уровень удовлетворённости сотрудника работой')

# %% [markdown]
# Чем больше удовлетворенность сотрудников тем реже они увольняются

# %% [markdown]
# ## Добавление нового входного признака

# %% [markdown]
# Добавим job_satisfaction_rate в тренировачный и тестовый датасеты путем предсказания этого значения моделью из первой задачи

# %%
#_list = ['employment_years','supervisor_evaluation']
#for i in _list:
#    data_two_train[i] = data_two_train[i].astype('object')

# %%
# обучаем модель на новых тренировачных данных
X = data_two_train.drop(['quit'],axis=1)
X = pd.DataFrame(
    preprocessor_tree.fit_transform(X),
    columns=preprocessor_tree.get_feature_names_out() ) 
X=X[list(features_names)]
job_train = model_one.predict(X)

# %%
data_test['job_satisfaction_rate'] = pred_one

# %%
# добавляем предсказаный столбец в третировачный и тестовые датасеты
data_two_train['job_satisfaction_rate']= job_train

# %% [markdown]
# ### Корреляционный анализ тренировачного датасета

# %%
cf2 =data_two_train.phik_matrix(interval_cols=numlist) 
cf2.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_bac1d_row0_col0,#T_bac1d_row1_col1,#T_bac1d_row2_col2,#T_bac1d_row3_col3,#T_bac1d_row4_col4,#T_bac1d_row5_col5,#T_bac1d_row6_col6,#T_bac1d_row7_col7,#T_bac1d_row8_col8,#T_bac1d_row9_col9{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_bac1d_row0_col1,#T_bac1d_row0_col3,#T_bac1d_row0_col4,#T_bac1d_row0_col8,#T_bac1d_row0_col9,#T_bac1d_row1_col0,#T_bac1d_row2_col5,#T_bac1d_row3_col0,#T_bac1d_row3_col6,#T_bac1d_row4_col0,#T_bac1d_row5_col2,#T_bac1d_row5_col7,#T_bac1d_row6_col3,#T_bac1d_row8_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_bac1d_row0_col2,#T_bac1d_row2_col0,#T_bac1d_row3_col5,#T_bac1d_row5_col3,#T_bac1d_row6_col7{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_bac1d_row0_col5,#T_bac1d_row5_col0{
#             background-color:  #ecf4fb;
#             color:  #000000;
# ...

# %% [markdown]
# Мультиколлинеарности нет

# %% [markdown]
# ### Корреляционный анализ тестового датасета

# %%
cf2 =data_test.phik_matrix(interval_cols=numlist) 
cf2.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_e579f_row0_col0,#T_e579f_row1_col1,#T_e579f_row2_col2,#T_e579f_row3_col3,#T_e579f_row4_col4,#T_e579f_row5_col5,#T_e579f_row6_col6,#T_e579f_row7_col7,#T_e579f_row8_col8,#T_e579f_row9_col9{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_e579f_row0_col1,#T_e579f_row0_col3,#T_e579f_row0_col4,#T_e579f_row0_col5,#T_e579f_row0_col8,#T_e579f_row1_col0,#T_e579f_row1_col6,#T_e579f_row2_col5,#T_e579f_row2_col9,#T_e579f_row3_col0,#T_e579f_row3_col6,#T_e579f_row4_col0,#T_e579f_row4_col5,#T_e579f_row5_col0,#T_e579f_row5_col2,#T_e579f_row5_col4,#T_e579f_row5_col7,#T_e579f_row6_col1,#T_e579f_row6_col3,#T_e579f_row7_col5,#T_e579f_row8_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_e579f_row0_col2,#T_e579f_row2_col0{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_e579f_row0_col6,#T_e579f_row6_col0{
#             background-color:  #ebf3fb;
# ...

# %% [markdown]
# Мультиколлинеарности нет

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Присоеденим целевой признак к тестовым данным, чтобы в будущем у y_test был плавильный порядок

# %%
list(data_two_train['quit'].unique())
le = LabelEncoder()
le.fit(list(data_two_train['quit'].unique()))
LabelEncoder()
# Out:
# LabelEncoder()

# %%
data_two_train['quit'] = le.transform(data_two_train['quit'])
data_test['quit'] = le.transform(data_test['quit'])

# %%
# разбиваем датасет на тренировачные и валидационные 
X_train = data_two_train.drop(['quit'],axis=1)
y_train = data_two_train['quit']

# %%
# разбиваем тестовый датасет
X_test = data_test.drop(['quit'],axis=1)
y_test = data_test['quit']

# %%
#  разбиваем стобцы на категориальные и количественные
selector = SelectKBest(f_classif, k=14)
sel_tree = SelectKBest(mutual_info_classif, k=10)
col_ohe_lr = list(X_train.select_dtypes(include='object').columns)
col_ohe_tree = list(X_train.select_dtypes(include='object').columns)
col_ord = ['level','workload']
col_num = list(X_train.select_dtypes(exclude='object').columns)

# %%
# пайплан для кодирования методом OneHotEncoder
pipe_ohe = Pipeline([( 'ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse=False))])
# пайплан для кодирования методом OrdinalEncoder
pipe_ord = ord_pipe = Pipeline([('ord',  OrdinalEncoder(categories=[ 
    ['junior','middle','sinior'],
    ['low','medium','high']
    
   ]))
    ])

# %%
preprocessor_lr = ColumnTransformer(
    [
    ('ohe', pipe_ohe, col_ohe_lr),
    ('num', RobustScaler(), col_num)
    ], 
    remainder='passthrough') 
preprocessor_tree = ColumnTransformer(
    [
    ('ohe', pipe_ohe, col_ohe_tree),
    ('ord', pipe_ord, col_ord),
    ('num', StandardScaler(), col_num)
    ], 
    remainder='passthrough')

# %%
param_grid_log = [
   # словарь для модели KNeighborsClassifier() 
   {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(15, 19),
        'models__metric':['cityblock','euclidean','l1','l2'],
        'selector__k': range(10,15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough'] 
    },
    
     # словарь для модели LogisticRegression()
  
    {
        'models': [LogisticRegression(solver='saga',
            random_state=RANDOM_STATE)],
        'models__C': [0.1,0.2,  0.3, 0.5,0.8,1,2,3,5,10],
        'models__penalty':['l1','l2','none'],
        'selector__k': range(7,15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']  
    },
 
    ]

# %%
# создаем пайплан для  модели дерево решений
pipe_dtc = Pipeline(
    [('preprocessor', preprocessor_tree),
     ('selector', sel_tree),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))]) 
# создаем пайплан для линейной  модели 
pipe_lr = Pipeline(
    [('preprocessor', preprocessor_lr),
    ('selector', selector),
    ('models', LogisticRegression(solver='saga',
            random_state=RANDOM_STATE))])

# %%
param_tree = [
  # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(10,15),
        'models__min_samples_leaf': range(6,10),
        'models__max_features': range(7,12),
        'models__min_samples_split': range(4, 8),
        'selector__k': range(8,15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),RobustScaler(), 'passthrough']  
    },]

# %% [markdown]
# ##  Обучение моделей

# %% [markdown]
# Найдем лучшую модель из логической или метрических моделей

# %%
grid = GridSearchCV(
    pipe_lr, 
    param_grid_log,
    cv=5, 
    scoring='roc_auc',  
    n_jobs=-1
)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         sparse=False))]),
#                                                                          ['dept',
#                                                                           'level',
#                                                                           'workload',
#                                                                           'last_year_promo',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', grid.best_estimator_)
print ('Метрика кросс-валидации лучшей модели на тренировочной выборке:', grid.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'level', 'workload',
#                                                    'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('num', RobustScaler(),
#                                                   ['employment_years',
#                                                    'supervisor_evaluation',
#                                                    'salary',
# ...

# %%
result_log = pd.DataFrame(grid.cv_results_)
ind=result_log.index[result_log['rank_test_score']==1]
result_log.loc[ind[0],'params']
# Out:
# {'models': LogisticRegression(random_state=42, solver='saga'),
#  'models__C': 10,
#  'models__penalty': 'l1',
#  'preprocessor__num': RobustScaler(),
#  'selector__k': 14}

# %%
# значения гипер параметров лучшей модели
result = pd.DataFrame(randomized_search.cv_results_)
ind=result.index[result['rank_test_score']==1]
result.loc[ind[0],'params']
# Out:
# {'selector__k': 8,
#  'preprocessor__num': 'passthrough',
#  'models__min_samples_split': 7,
#  'models__min_samples_leaf': 9,
#  'models__max_features': 10,
#  'models__max_depth': 12,
#  'models': DecisionTreeClassifier(random_state=42)}

# %% [markdown]
# Лучшая модель - LogisticRegression(random_state=42, solver='saga'),
# - 'C': 10,
# - 'penalty': 'l1',
# - Маштабирование: RobustScaler(),
# При 14 признаках эта модель выдает лучший результат.
# - Метрика кросс-валидации на тренировачной выборке

# %%
X_train_lr_final =pd.DataFrame(
    preprocessor_lr.fit_transform(X_train),
    columns=preprocessor_lr.get_feature_names_out() )   

X_test_lr_final =pd.DataFrame(
    preprocessor_lr.fit_transform(X_test),
    columns=preprocessor_lr.get_feature_names_out())
    
selector.fit(X_train_lr_final, y_train)
features_names = selector.get_feature_names_out()
X_train_knn_final = X_train_lr_final[list(features_names)]
X_test_knn_final = X_test_lr_final[list(features_names)]

# %%
#оценка модели на тестовых данных
# Оценка лучшей модели на обучающей выборке
model_two = LogisticRegression(C=10, penalty='l1', random_state=42,
                                    solver='saga')
model_two.fit(X_train_lr_final, y_train)

y_test_pred = model_two.predict_proba(X_test_lr_final)
roc_auc_score(y_test, y_test_pred [:,1])
# Out:
# 0.9163147731089116

# %%
dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(X_train_knn_final, y_train)
dpred = dummy_clf.predict_proba(X_test_knn_final)[:,1]
roc_auc_score(y_test,dpred)
# Out:
# 0.5

# %% [markdown]
# -оценка DummyClassifier = 0.5, Оценка модели KNeighborsClassifier - 0.91

# %% [markdown]
# ## вывод

# %% [markdown]
# Провели исследования и моделирование.
# - Были убраны пропуски и пустые значения у  нескольких столбцов были изменены тип данных.
# - Исправлены выбросы .
# - В качестве моделей были обучены логическая регрессия, модельk-ближайших соседей и дерево классификации.Была определена лучшая модель.
#
# Мы нашли лучшую модель- LogisticRegression(random_state=42, solver='saga'),
# - 'C': 10,
# - 'penalty': 'l1',
# - Маштабирование: RobustScaler(),
# При 14 признаках эта модель выдает лучший результат по метрике Roc_auc в 0.91.

# %% [markdown]
# # Общий вывод

# %% [markdown]
# Было поставленно две задчи:
# - Первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# - Ваша вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.

# %% [markdown]
# Были проведены работы:
# - Предобработка данных (Найдены и удалены пропуски)
# - Исследовательский и корреляционный анализ
# - подготовка к моделированию( Создание пайпланов).
# -Для второй задачи в обучающую выборку был добавлен новый признак путем обучение выборки на лучшей модели из первой задачи.
# - моделирование, Были определены лучшие модели:
#  1. Первая модель - DecisionTreeRegressor() при 14 признаках
# - max_depth': 17,
# - max_features': 11,
# - min_samples_leaf': 3,
# - min_samples_split': 9,
# - 'метод масштабирования: StandardScaler(),
#
#   2.Вторая Лучшая модель - LogisticRegression(random_state=42, solver='saga'),
# - 'SelectKBest': 14
# - 'C': 10,
# - 'penalty': 'l1',
# - Маштабирование: RobustScaler(),

# %% [markdown]
# Для бизнеса:
#
# Стоит обратить внимание на то что больше всего уволенных имеют:
# - низкую зарплату ,
# - уровень junior
# - низкую рабочую нагрузку.
#
# Возможно привлекать новичков к большему количеству проектов или давать больше работы внутри проектов в которых они работают. Больше всего текучка в отделе продаж и технологий.
